# %%
a=(1,[2,3],4)

a[1].append(4)
a
# Out:
# (1, [2, 3, 4], 4)

# %%
d={}
len(d.keys())

def add(name,marks):
    d[len(d.keys())+1] = [name,marks]
    return d
# Out:
# {1: ['Harshit', 99]}

# %%
d={1:2,3:4}
d.items()
# Out:
# dict_items([(1, 2), (3, 4)])
